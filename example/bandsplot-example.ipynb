# %% [markdown]
# # **A Jupyter widget to plot the bandstructure and density of states (DOS)**
#
# <hr style="height:1px;border:none;color:#cccccc;background-color:#cccccc;" />

# %% [markdown]
# <p style="text-align: justify;font-size:15px">
#     This is a Jupyter widget, which plots the bandstructure and density of states from given json files.
# </p>
#
# ## **Input json files**
#
# <p style="text-align: justify;font-size:15px">
#     On the left, it plots the bandstructures. One can input several bandstructure json files as a list.
#     The figure on the right shows the density of states, which can only show one DOS plot. The json files
#     for the bandstructures can be generated from AiiDA with the verdi command:
# </p>
#
# ```bash
# verdi data bands export --format json <IDENTIFIER>
# ```
#
# <p style="text-align: justify;font-size:15px">
#     The json format for the DOS can be checked in the github repository.
# </p>
#
# <a href="https://raw.githubusercontent.com/osscar-org/widget-bandsplot/develop/example/Si_pdos_data.json">
# https://raw.githubusercontent.com/osscar-org/widget-bandsplot/develop/example/Si_pdos_data.json</a>
#
# <p style="text-align: justify;font-size:15px">
#     Here, one needs to use the json package to load the json file and pass it to the widget.
# </p>
#
# ```python
# with open('Si_bandsdata.json', 'r') as file:
#     data1 = json.load(file)
#
# with open('Si_pdos_data.json', 'r') as file:
#     data2 = json.load(file)
# ```
#
# ## **Fermi energy**
#
# <p style="text-align: justify;font-size:15px">
#     In default, the Fermi energy is reading from the DOS json file. And bandstructure and density
#     of states plots are aligned to the Fermi energy (shift the Fermi energy to zero). However, one
#     can also give the Fermi energy in the options. By setting fermiEnergy = 0.0, there is no shiftting
#     for the bandstructure and DOS.
# </p>
#
# <p style="text-align: justify;font-size:15px">
#     In the default plot for the DOS, there is a horizontal line to highlight the Fermi level. One
#     can turn it off by setting showFermi = False.
# </p>
#
# ## **Usage of the widget**
#
# <p style="text-align: justify;font-size:15px">
#     Remeber to pass the bandstructure data as a list of json objects. yLmit sets the energy ranges
#     for the plots.
# </p>
#
# ```python
# w1 = BandsPlotWidget(bands=[data1], dos=data2, plot_fermilevel = True, ylimit = {"ymin": -13.0, "ymax": 10.0})
# display(w1)
# ```

# %%
from widget_bandsplot import *
import json

# %%
with open('Si_bands.json', 'r') as file:
    data1 = json.load(file)
    
with open('Si_dos.json', 'r') as file:
    data2 = json.load(file)

# %%
w1 = BandsPlotWidget(bands=[data1], dos=data2, plot_fermilevel = True, ylimit = {"ymin": -13.0, "ymax": 10.0})
display(w1)

# %% [markdown]
# ```python
# w2 = BandsPlotWidget(bands=[data1], plot_fermilevel = True, ylimit = {"ymin": -13.0, "ymax": 10.0})
# display(w2)
# ```

# %%
w2 = BandsPlotWidget(bands=[data1], plot_fermilevel = True, ylimit = {"ymin": -13.0, "ymax": 10.0})
display(w2)

# %% [markdown]
# ```python
# w3 = BandsPlotWidget(dos=data2, plot_fermilevel = True, ylimit = {"ymin": -13.0, "ymax": 10.0})
# display(w3)
# ```

# %%
w3 = BandsPlotWidget(dos=data2, plot_fermilevel = True, ylimit = {"ymin": -13.0, "ymax": 10.0})
display(w3)

# %% [markdown]
# <p style="text-align: justify;font-size:15px">
#     There are inputrea and buttons below the figures. The inputarea can be used to edit
#     the path. The buttons are used to view the figures.
# </p>
#
# <p style="text-align: justify;font-size:15px">
#     One can also reuse the data from the widget and plot the DOS by matplotlib.
# </p>
#
# ```python
# import matplotlib
# import matplotlib.pyplot as plt
# import numpy as np
#
# fig, ax = plt.subplots()
# ax.plot(w.tdos_x, w.tdos_y, 'k')
#
# ax.fill_between(w.tdos_x, 0, w.tdos_y, color="red")
# ax.set_ylim([0, 2.2])
# ax.axvline(w.fermi_energy, color='black')
#
# plt.show()
# ```

# %%
# %matplotlib widget

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
ax.plot(w1.tdos_x, w1.tdos_y, 'k')

ax.fill_between(w1.tdos_x, 0, w1.tdos_y, color="red")
ax.set_ylim([0, 2.2])
ax.axvline(w1.dos_fermienergy, color='black')

plt.show()
